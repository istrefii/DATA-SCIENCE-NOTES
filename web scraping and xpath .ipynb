# %%
# Indrit Istrefi
# using web scraping and xpath to collect data from a website
# using sqlite on the data

# %%
#import modules 
import requests 
import pandas as pd
import sqlite3
import lxml.html
from IPython.core.display import display, HTML

# %%
# request get on the url
h1= requests.get('https://pokemondb.net/pokedex/all')

# %%
# using the lxml.html function on the request get above
d1= lxml.html.fromstring(h1.content)

# %%
#getting the table by the id
pokedex=d1.get_element_by_id('pokedex')

# %%
pokedex
# Out:
# <Element table at 0x7fc08b83d450>

# %%
# getting the children of the tablebody
tablebody= pokedex.getchildren()[1]
tablebody.getchildren()[0].text_content()
# Out:
# '\n001 BulbasaurGrass Poison\n318\n45\n49\n49\n65\n65\n45\n'

# %%
# trying to find the first index of the table
tablebody.getchildren()[0].getchildren()[0].text_content()
# Out:
# '001'

# %%
# getting the length of the table
len(tablebody.getchildren()[0:])
# Out:
# 1045

# %%
#creating a dictionary with all the column names
data = {
    "#": [],
    "Name":     [],
    "Type":     [],
    "HP":       [],
    "Attack":   [],
    "Defense":  [],
    "Sp_Atk":   [],
    "Sp_Def":   [],
    "Speed":    [],
}
# creating a for loop to get each value in the table
for row in tablebody.getchildren()[0:]:
    data["#"].append(row.getchildren()[0].text_content().strip())
    data["Name"].append(row.getchildren()[1].text_content().strip())
    data["Type"].append(row.getchildren()[2].text_content().strip())
    data["HP"].append(row.getchildren()[3].text_content().strip())
    data["Attack"].append(row.getchildren()[4].text_content().strip())
    data["Defense"].append(row.getchildren()[5].text_content().strip())
    data["Sp_Atk"].append(row.getchildren()[6].text_content().strip())
    data["Sp_Def"].append(row.getchildren()[7].text_content().strip())
    data["Speed"].append(row.getchildren()[8].text_content().strip())
# creating the data frame
df= pd.DataFrame(data)
df
# Out:
#         #                    Name           Type   HP Attack Defense Sp_Atk  \
# 0     001               Bulbasaur   Grass Poison  318     45      49     49
# 1     002                 Ivysaur   Grass Poison  405     60      62     63
# 2     003                Venusaur   Grass Poison  525     80      82     83
# 3     003  Venusaur Mega Venusaur   Grass Poison  625     80     100    123
# 4     004              Charmander           Fire  309     39      52     43
# ...   ...                     ...            ...  ...    ...     ...    ...
# 1040  896               Glastrier            Ice  580    100     145    130
# 1041  897               Spectrier          Ghost  580    100      65     60
# 1042  898                 Calyrex  Psychic Grass  500    100      80     80
# 1043  898       Calyrex Ice Rider    Psychic Ice  680    100     165    150
# 1044  898    Calyrex Shadow Rider  Psychic Ghost  680    100      85     80
#
#      Sp_Def Speed
# 0        65    65
# ...

# %%
# printing the last row of the table by each column name 
print("#", row.getchildren()[0].text_content().strip())
print("Name", row.getchildren()[1].text_content().strip())
print("Type", row.getchildren()[2].text_content().strip())
print("HP", row.getchildren()[3].text_content().strip())
print("Attack", row.getchildren()[4].text_content().strip())
print("Defense", row.getchildren()[5].text_content().strip())
print("Sp_Atk", row.getchildren()[6].text_content().strip())
print("Sp_Def", row.getchildren()[7].text_content().strip())
print("Speed", row.getchildren()[8].text_content().strip())
# Out:
# # 898
# Name Calyrex Shadow Rider
# Type Psychic Ghost
# HP 680
# Attack 100
# Defense 85
# Sp_Atk 80
# Sp_Def 165
# Speed 100

# %%
# now using xpath to get a certain table from a webpage
# setting url variable as the url of the page
url = ('https://en.wikipedia.org/wiki/List_of_highest-grossing_films')

# %%
# using the requests.get function on the url
r = requests.get(url)
# using the lxml.html.fromstring on the r with the content 
M1 = lxml.html.fromstring(r.content)
print(M1)
# Out:
# <Element html at 0x7fc06e69b810>

# %%
# get the xpath link using the developers tools
elements= M1.xpath('//*[@id="mw-content-text"]/div[1]/table[1]')
#set the tbody
tbody = elements[0].getchildren()

# %%
# getting the children of the tbody and displaying the content
tbody[1].getchildren()[0].text_content()
# Out:
# '\nRank\n\nPeak\n\nTitle\n\nWorldwide gross\n\nYear\n\nReference(s)\n'

# %%
# creating a dictionary of the column names
data1 = {
    "Rank":  [],
    "Peak": [],
    "Title": [],
    "WorldWide_Gross": [],
    "Year": [],
    "References": [],
}
# creating a for low for each column to append the content 
for row in tbody[1].getchildren()[0:]:
    data1["Rank"].append(row.getchildren()[0].text_content().strip())
    data1["Peak"].append(row.getchildren()[1].text_content().strip())
    data1["Title"].append(row.getchildren()[2].text_content().strip())
    data1["WorldWide_Gross"].append(row.getchildren()[3].text_content().strip())
    data1["Year"].append(row.getchildren()[4].text_content().strip())
    data1["References"].append(row.getchildren()[5].text_content().strip())
df1= pd.DataFrame(data1)
df1.head(10)
# Out:
#    Rank  Peak                         Title  WorldWide_Gross  Year  \
# 0  Rank  Peak                         Title  Worldwide gross  Year
# 1     1     1             Avengers: Endgame   $2,797,800,564  2019
# 2     2     1                        Avatar   $2,790,439,000  2009
# 3     3     1                       Titanic   $2,194,439,542  1997
# 4     4     3  Star Wars: The Force Awakens   $2,068,223,624  2015
# 5     5     4        Avengers: Infinity War   $2,048,359,754  2018
# 6     6     3                Jurassic World   $1,671,713,208  2015
# 7     7     7                 The Lion King   $1,656,943,394  2019
# 8     8     3                  The Avengers   $1,518,812,988  2012
# 9     9     4                     Furious 7   $1,516,045,911  2015
#
#      References
# 0  Reference(s)
# 1    [# 1][# 2]
# 2    [# 3][# 4]
# 3    [# 5][# 6]
# 4    [# 7][# 8]
# 5   [# 9][# 10]
# 6  [# 11][# 12]
# 7   [# 13][# 2]
# 8  [# 14][# 15]
# 9  [# 16][# 17]

# %%
# printing the last column of the table
print("Rank", row.getchildren()[0].text_content().strip())
print("Peak", row.getchildren()[1].text_content().strip())
print("Title", row.getchildren()[2].text_content().strip())
print("WorldWide_Gross", row.getchildren()[3].text_content().strip())
print("Year", row.getchildren()[4].text_content().strip())
print("References", row.getchildren()[5].text_content().strip())
# Out:
# Rank 50
# Peak 2
# Title The Lion King
# WorldWide_Gross $968,483,777
# Year 1994
# References [# 79][# 64]

# %%
# looking at the info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   #        1045 non-null   object
#  1   Name     1045 non-null   object
#  2   Type     1045 non-null   object
#  3   HP       1045 non-null   object
#  4   Attack   1045 non-null   object
#  5   Defense  1045 non-null   object
#  6   Sp_Atk   1045 non-null   object
#  7   Sp_Def   1045 non-null   object
#  8   Speed    1045 non-null   object
# dtypes: object(9)
# memory usage: 73.6+ KB

# %%
# seeing how many different type pokemons 
df.Type.value_counts()
# Out:
# Water              72
# Normal             71
# Psychic            45
# Grass              43
# Fire               34
#                    ..
# Ground Electric     1
# Ice Fairy           1
# Electric Fire       1
# Ghost Fairy         1
# Ice Fire            1
# Name: Type, Length: 192, dtype: int64

# %%
# creating a data
fire_water_type =df[df.Type.isin(["Fire", "Water"])]
#another way to create it using a for loop
for row in df[df.Type.isin(["Fire", "Water"])].itertuples():
   print(row[1:])
# Out:
# ('004', 'Charmander', 'Fire', '309', '39', '52', '43', '60', '50')
# ('005', 'Charmeleon', 'Fire', '405', '58', '64', '58', '80', '65')
# ('007', 'Squirtle', 'Water', '314', '44', '48', '65', '50', '64')
# ('008', 'Wartortle', 'Water', '405', '59', '63', '80', '65', '80')
# ('009', 'Blastoise', 'Water', '530', '79', '83', '100', '85', '105')
# ('009', 'Blastoise Mega Blastoise', 'Water', '630', '79', '103', '120', '135', '115')
# ('037', 'Vulpix', 'Fire', '299', '38', '41', '40', '50', '65')
# ('038', 'Ninetales', 'Fire', '505', '73', '76', '75', '81', '100')
# ('054', 'Psyduck', 'Water', '320', '50', '52', '48', '65', '50')
# ('055', 'Golduck', 'Water', '500', '80', '82', '78', '95', '80')
# ('058', 'Growlithe', 'Fire', '350', '55', '70', '45', '70', '50')
# ('059', 'Arcanine', 'Fire', '555', '90', '110', '80', '100', '80')
# ('060', 'Poliwag', 'Water', '300', '40', '50', '40', '40', '40')
# ('061', 'Poliwhirl', 'Water', '385', '65', '65', '65', '50', '50')
# ...

# %%
# seeing the len of the row
len(row[1:])
# Out:
# 9

# %%
# creating the db 
db = sqlite3.connect(":memory")
# creating the cursor to the db
cursor = db.cursor()
# executing the table, calling it PKS_TABLE with the columns 
cursor.execute("""
    CREATE TABLE PKS_TABLE(NUMBER, NAME, TYPE, HP, ATTACK, DEFENSE, SP_ATK, SP_DEF, SPEED)
""")
#using the for loop to insert the values
for row in df[df.Type.isin(["Fire", "Water"])].itertuples():
    insert_sql_syntax = """
        INSERT INTO PKS_TABLE(NUMBER, NAME, TYPE, HP, ATTACK, DEFENSE, SP_ATK, SP_DEF, SPEED)
        VALUES (?,?,?,?,?,?,?,?,?)
    """
    cursor.execute(insert_sql_syntax, row[1:])
    print (row[1:])
# db.close()
# Out:
# ('004', 'Charmander', 'Fire', '309', '39', '52', '43', '60', '50')
# ('005', 'Charmeleon', 'Fire', '405', '58', '64', '58', '80', '65')
# ('007', 'Squirtle', 'Water', '314', '44', '48', '65', '50', '64')
# ('008', 'Wartortle', 'Water', '405', '59', '63', '80', '65', '80')
# ('009', 'Blastoise', 'Water', '530', '79', '83', '100', '85', '105')
# ('009', 'Blastoise Mega Blastoise', 'Water', '630', '79', '103', '120', '135', '115')
# ('037', 'Vulpix', 'Fire', '299', '38', '41', '40', '50', '65')
# ('038', 'Ninetales', 'Fire', '505', '73', '76', '75', '81', '100')
# ('054', 'Psyduck', 'Water', '320', '50', '52', '48', '65', '50')
# ('055', 'Golduck', 'Water', '500', '80', '82', '78', '95', '80')
# ('058', 'Growlithe', 'Fire', '350', '55', '70', '45', '70', '50')
# ('059', 'Arcanine', 'Fire', '555', '90', '110', '80', '100', '80')
# ('060', 'Poliwag', 'Water', '300', '40', '50', '40', '40', '40')
# ('061', 'Poliwhirl', 'Water', '385', '65', '65', '65', '50', '50')
# ...

# %%
# setting all the data where type=fire 
cursor.execute("""
    SELECT
    *
    FROM 
    PKS_TABLE
    WHERE
    TYPE='Fire'
""").fetchall()
# Out:
# [('004', 'Charmander', 'Fire', '309', '39', '52', '43', '60', '50'),
#  ('005', 'Charmeleon', 'Fire', '405', '58', '64', '58', '80', '65'),
#  ('037', 'Vulpix', 'Fire', '299', '38', '41', '40', '50', '65'),
#  ('038', 'Ninetales', 'Fire', '505', '73', '76', '75', '81', '100'),
#  ('058', 'Growlithe', 'Fire', '350', '55', '70', '45', '70', '50'),
#  ('059', 'Arcanine', 'Fire', '555', '90', '110', '80', '100', '80'),
#  ('077', 'Ponyta', 'Fire', '410', '50', '85', '55', '65', '65'),
#  ('078', 'Rapidash', 'Fire', '500', '65', '100', '70', '80', '80'),
#  ('126', 'Magmar', 'Fire', '495', '65', '95', '57', '100', '85'),
#  ('136', 'Flareon', 'Fire', '525', '65', '130', '60', '95', '110'),
#  ('155', 'Cyndaquil', 'Fire', '309', '39', '52', '43', '60', '50'),
#  ('156', 'Quilava', 'Fire', '405', '58', '64', '58', '80', '65'),
#  ('157', 'Typhlosion', 'Fire', '534', '78', '84', '78', '109', '85'),
#  ('218', 'Slugma', 'Fire', '250', '40', '40', '40', '70', '40'),
# ...

# %%
# setting all the data where type = water
cursor.execute("""
    SELECT
    *
    FROM 
    PKS_TABLE
    WHERE
    TYPE='Water'
""").fetchall()
# Out:
# [('007', 'Squirtle', 'Water', '314', '44', '48', '65', '50', '64'),
#  ('008', 'Wartortle', 'Water', '405', '59', '63', '80', '65', '80'),
#  ('009', 'Blastoise', 'Water', '530', '79', '83', '100', '85', '105'),
#  ('009',
#   'Blastoise Mega Blastoise',
#   'Water',
#   '630',
#   '79',
#   '103',
#   '120',
#   '135',
#   '115'),
#  ('054', 'Psyduck', 'Water', '320', '50', '52', '48', '65', '50'),
#  ('055', 'Golduck', 'Water', '500', '80', '82', '78', '95', '80'),
#  ('060', 'Poliwag', 'Water', '300', '40', '50', '40', '40', '40'),
#  ('061', 'Poliwhirl', 'Water', '385', '65', '65', '65', '50', '50'),
#  ('086', 'Seel', 'Water', '325', '65', '45', '55', '45', '70'),
#  ('090', 'Shellder', 'Water', '305', '30', '65', '100', '45', '25'),
#  ('098', 'Krabby', 'Water', '325', '30', '105', '90', '25', '25'),
#  ('099', 'Kingler', 'Water', '475', '55', '130', '115', '50', '50'),
#  ('116', 'Horsea', 'Water', '295', '30', '40', '70', '70', '25'),
# ...

# %%
# selecting all the data from the PKS_TABLE where type = water or hp was greater then 550
cursor.execute("""
    SELECT
    *
    FROM 
    PKS_TABLE
    WHERE
    TYPE = 'WATER'
      OR
    HP > '550'
""").fetchall()
# Out:
# [('009',
#   'Blastoise Mega Blastoise',
#   'Water',
#   '630',
#   '79',
#   '103',
#   '120',
#   '135',
#   '115'),
#  ('059', 'Arcanine', 'Fire', '555', '90', '110', '80', '100', '80'),
#  ('244', 'Entei', 'Fire', '580', '115', '115', '85', '90', '75'),
#  ('245', 'Suicune', 'Water', '580', '100', '75', '115', '90', '115'),
#  ('382', 'Kyogre', 'Water', '670', '100', '100', '90', '150', '140'),
#  ('382',
#   'Kyogre Primal Kyogre',
#   'Water',
#   '770',
#   '100',
#   '150',
#   '90',
#   '180',
#   '160'),
#  ('490', 'Manaphy', 'Water', '600', '100', '100', '100', '100', '100'),
#  ('746',
#   'Wishiwashi School Form',
#   'Water',
#   '620',
#   '45',
#   '140',
#   '130',
#   '140',
#   '135')]

# %%
# selecting the hp column for the PKS_TABLE
cursor.execute("""
    SELECT 
    HP
    FROM
    PKS_TABLE


""").fetchall()
# Out:
# [('309',),
#  ('405',),
#  ('314',),
#  ('405',),
#  ('530',),
#  ('630',),
#  ('299',),
#  ('505',),
#  ('320',),
#  ('500',),
#  ('350',),
#  ('555',),
#  ('300',),
#  ('385',),
#  ('410',),
#  ('500',),
#  ('325',),
#  ('305',),
#  ('325',),
#  ('475',),
#  ('295',),
#  ('440',),
#  ('320',),
#  ('450',),
#  ('340',),
#  ('495',),
#  ('200',),
#  ('525',),
#  ('525',),
#  ('309',),
#  ('405',),
#  ('534',),
#  ('314',),
#  ('405',),
#  ('530',),
#  ('500',),
#  ('250',),
#  ('300',),
#  ('480',),
#  ('365',),
#  ('580',),
#  ('580',),
#  ('310',),
#  ('310',),
#  ('400',),
#  ('500',),
#  ('470',),
#  ('308',),
#  ('200',),
#  ('540',),
#  ('420',),
#  ('420',),
#  ('345',),
#  ('485',),
#  ('485',),
#  ('330',),
#  ('670',),
#  ('770',),
#  ('309',),
#  ('314',),
#  ('405',),
#  ('330',),
#  ('495',),
#  ('325',),
#  ('330',),
#  ('460',),
#  ('540',),
#  ('480',),
#  ('600',),
#  ('308',),
#  ('308',),
#  ('413',),
#  ('528',),
#  ('316',),
#  ('498',),
#  ('316',),
# ...

# %%
# selecting all the columns of the PKS_TABLE where name= 'Entei'
cursor.execute("""
    SELECT 
    *
    FROM
    PKS_TABLE
    WHERE
    NAME = 'Entei'

""").fetchall()
# Out:
# [('244', 'Entei', 'Fire', '580', '115', '115', '85', '90', '75')]
